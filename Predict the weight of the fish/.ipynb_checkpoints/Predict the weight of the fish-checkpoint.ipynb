# %% [markdown]
# ## STEP 1: Import the required files
#
# - numpy: numpy is the core library for computing in python. It is used for working with arrays and matrices.
# - pandas: used for data manipulation and analysis.
# - matplotlib: it's plotting library, and we are going to use it for data visualization.
# - seaborn: it is also data visualization library, based on matplotlib.
# - linear_model: sklearn linear regression model.
# - train_test_split: helper funtion from sklearn library for splitting the dataset.
# - sklearn.metrics: library encapsulate function to measure the model performance.
# - polynomialFeatures: this used to generate polynomial features. in this study we are going to generate second degree features.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from sklearn.preprocessing import PolynomialFeatures
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## STEP 2: Load the data

# %%
df = pd.read_csv(r"D:\Personal Project\DA_DE\Predict the weight of the fish\Fish (Practice).csv")

print('Dimension of dataset:', df.shape)
df.head(5) # head(n) return first n records only. can also use sample(n) for random n records.
# Out:
# Dimension of dataset: (159, 7)
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %% [markdown]
# # Step 3: Understand The Data
# * There are total 159 rows(training samples) and 7 columns in dataset.
# * Each column details are as below
#
# | Column Name | Details
# | ------------|--------------
# | Species     | Species name of fish
# | Weight      | Weight of fish in gram
# | Length1     | Vertical length in CM
# | Length2     | Diagonal length in CM
# | Length3     | Cross length in CM
# | Height      | Height in CM
# | Width       | Diagonal width in CM
#
# * Features/input values/independent variables are 'Species', 'Length1','Length2', 'Length3', 'Height' and 'Width'
# * Target/output value/dependent variable is 'Weight'
# * So, we have to estimate the weight of the fish based on its measurement values.
#
# Let's change the name of columns lenght1,length2 and length3  as per the content of it.

# %%
df1 = df.rename(columns = {'Length1':'VerticalLen', 'Length2':'DiagonalLen', 'Length3':'CrossLen'})
df1.sample(5)
# Out:
#        Species  Weight  VerticalLen  DiagonalLen  CrossLen   Height   Width
# 75       Perch    51.5         15.0         16.2      17.2   4.5924  2.6316
# 25       Bream   725.0         31.8         35.0      40.9  16.3600  6.0532
# 136       Pike   540.0         40.1         43.0      45.8   7.7860  5.1296
# 116      Perch   900.0         36.5         39.0      41.4  11.1366  7.4934
# 59   Whitefish   800.0         33.7         36.4      39.6  11.7612  6.5736

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Species      159 non-null    object
#  1   Weight       159 non-null    float64
#  2   VerticalLen  159 non-null    float64
#  3   DiagonalLen  159 non-null    float64
#  4   CrossLen     159 non-null    float64
#  5   Height       159 non-null    float64
#  6   Width        159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %% [markdown]
# ## STEP 4: Data analysis cleaning and visualization
#
# ### Corelation check
# - correlation helps us investigate and establish ralationships between variables
# - not that high amount of corralation between independent varibles suggest that linear regression estimation will ve unreliable

# %%
df1.corr().style.background_gradient(cmap = 'Greens')
# Out:
# <style type="text/css">
# #T_0df85_row0_col0, #T_0df85_row1_col1, #T_0df85_row1_col2, #T_0df85_row2_col1, #T_0df85_row2_col2, #T_0df85_row3_col3, #T_0df85_row4_col4, #T_0df85_row5_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_0df85_row0_col1, #T_0df85_row0_col2 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_0df85_row0_col3 {
#   background-color: #258d47;
#   color: #f1f1f1;
# }
# #T_0df85_row0_col4 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_0df85_row0_col5 {
#   background-color: #86cc85;
#   color: #000000;
# }
# #T_0df85_row1_col0 {
#   background-color: #309950;
#   color: #f1f1f1;
# }
# #T_0df85_row1_col3 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_0df85_row1_col4, #T_0df85_row4_col0, #T_0df85_row4_col1, #T_0df85_row4_col2, #T_0df85_row4_col3, #T_0df85_row4_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_0df85_row1_col5 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_0df85_row2_col0 {
#   background-color: #2e964d;
#   color: #f1f1f1;
# }
# #T_0df85_row2_col3, #T_0df85_row3_col1 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_0df85_row2_col4 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_0df85_row2_col5 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_0df85_row3_col0 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_0df85_row3_col2 {
#   background-color: #00491d;
#   color: #f1f1f1;
# }
# #T_0df85_row3_col4 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_0df85_row3_col5 {
#   background-color: #94d390;
#   color: #000000;
# }
# #T_0df85_row5_col0 {
#   background-color: #50b264;
#   color: #f1f1f1;
# }
# #T_0df85_row5_col1, #T_0df85_row5_col2 {
#   background-color: #3ca559;
#   color: #f1f1f1;
# }
# #T_0df85_row5_col3 {
#   background-color: #4eb264;
#   color: #f1f1f1;
# }
# #T_0df85_row5_col4 {
#   background-color: #87cd86;
#   color: #000000;
# }
# </style>
# <table id="T_0df85">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0df85_level0_col0" class="col_heading level0 col0" >Weight</th>
#       <th id="T_0df85_level0_col1" class="col_heading level0 col1" >VerticalLen</th>
#       <th id="T_0df85_level0_col2" class="col_heading level0 col2" >DiagonalLen</th>
#       <th id="T_0df85_level0_col3" class="col_heading level0 col3" >CrossLen</th>
#       <th id="T_0df85_level0_col4" class="col_heading level0 col4" >Height</th>
#       <th id="T_0df85_level0_col5" class="col_heading level0 col5" >Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0df85_level0_row0" class="row_heading level0 row0" >Weight</th>
#       <td id="T_0df85_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0df85_row0_col1" class="data row0 col1" >0.915712</td>
#       <td id="T_0df85_row0_col2" class="data row0 col2" >0.918618</td>
#       <td id="T_0df85_row0_col3" class="data row0 col3" >0.923044</td>
#       <td id="T_0df85_row0_col4" class="data row0 col4" >0.724345</td>
#       <td id="T_0df85_row0_col5" class="data row0 col5" >0.886507</td>
#     </tr>
#     <tr>
#       <th id="T_0df85_level0_row1" class="row_heading level0 row1" >VerticalLen</th>
#       <td id="T_0df85_row1_col0" class="data row1 col0" >0.915712</td>
#       <td id="T_0df85_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0df85_row1_col2" class="data row1 col2" >0.999517</td>
#       <td id="T_0df85_row1_col3" class="data row1 col3" >0.992031</td>
#       <td id="T_0df85_row1_col4" class="data row1 col4" >0.625378</td>
#       <td id="T_0df85_row1_col5" class="data row1 col5" >0.867050</td>
#     </tr>
#     <tr>
#       <th id="T_0df85_level0_row2" class="row_heading level0 row2" >DiagonalLen</th>
#       <td id="T_0df85_row2_col0" class="data row2 col0" >0.918618</td>
#       <td id="T_0df85_row2_col1" class="data row2 col1" >0.999517</td>
#       <td id="T_0df85_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0df85_row2_col3" class="data row2 col3" >0.994103</td>
#       <td id="T_0df85_row2_col4" class="data row2 col4" >0.640441</td>
#       <td id="T_0df85_row2_col5" class="data row2 col5" >0.873547</td>
#     </tr>
#     <tr>
#       <th id="T_0df85_level0_row3" class="row_heading level0 row3" >CrossLen</th>
#       <td id="T_0df85_row3_col0" class="data row3 col0" >0.923044</td>
#       <td id="T_0df85_row3_col1" class="data row3 col1" >0.992031</td>
#       <td id="T_0df85_row3_col2" class="data row3 col2" >0.994103</td>
#       <td id="T_0df85_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0df85_row3_col4" class="data row3 col4" >0.703409</td>
#       <td id="T_0df85_row3_col5" class="data row3 col5" >0.878520</td>
#     </tr>
#     <tr>
#       <th id="T_0df85_level0_row4" class="row_heading level0 row4" >Height</th>
#       <td id="T_0df85_row4_col0" class="data row4 col0" >0.724345</td>
#       <td id="T_0df85_row4_col1" class="data row4 col1" >0.625378</td>
#       <td id="T_0df85_row4_col2" class="data row4 col2" >0.640441</td>
#       <td id="T_0df85_row4_col3" class="data row4 col3" >0.703409</td>
#       <td id="T_0df85_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_0df85_row4_col5" class="data row4 col5" >0.792881</td>
#     </tr>
#     <tr>
#       <th id="T_0df85_level0_row5" class="row_heading level0 row5" >Width</th>
#       <td id="T_0df85_row5_col0" class="data row5 col0" >0.886507</td>
#       <td id="T_0df85_row5_col1" class="data row5 col1" >0.867050</td>
#       <td id="T_0df85_row5_col2" class="data row5 col2" >0.873547</td>
#       <td id="T_0df85_row5_col3" class="data row5 col3" >0.878520</td>
#       <td id="T_0df85_row5_col4" class="data row5 col4" >0.792881</td>
#       <td id="T_0df85_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.rcParams['figure.figsize'] = (12, 7)
sns.heatmap(df1.corr(), annot = True)
plt.title('Correlation matrix')
# Out:
# Text(0.5, 1.0, 'Correlation matrix')

# %% [markdown]
# ### Reading Correlation Matrix
#
# - correlation coeffcient range from -1 to 1
# - sign(+/-) indicate the direction and amount incate the strength of corrlation
# - +1 means perfect positive relationship
# - 0 means no relationship
# - -1 means perfect negative ralationship
# - the correlation between 'VerticaLen', 'DiagonalLen' and 'Crosslen' is almost 1. This may cause 'Multicolinearity'.
#
# let's dropthe 'VerticalLen', 'DiagonalLen' and 'Crosslen', column

# %%
df2 = df1.drop(['VerticalLen', 'DiagonalLen', 'CrossLen'], axis = 1)
